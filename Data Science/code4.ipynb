# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv('data/epa-sea-level.csv')

# %%
df
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0    1880                  0.000000          -0.952756           0.952756
# 1    1881                  0.220472          -0.732283           1.173228
# 2    1882                 -0.440945          -1.346457           0.464567
# 3    1883                 -0.232283          -1.129921           0.665354
# 4    1884                  0.590551          -0.283465           1.464567
# ..    ...                       ...                ...                ...
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 0                        NaN
# ...

# %%
x = df['Year']
y = df['CSIRO Adjusted Sea Level']

# Create scatter plot
plt.scatter(x, y)

# %%
# Plot a new line of best fit just using the data from year 2000 through the most recent year in the dataset. Make the line also go through the year 2050 to predict the sea level rise in 2050 if the rate of rise continues as it has since the year 2000.

df2 = df[df['Year'] >= 2000]

x3 = df2['Year']
y3 = df2['CSIRO Adjusted Sea Level']

slope2, intercept2, r_value2, p_value2, std_err2 = linregress(x3, y3)

plt.scatter(x3, y3)

plt.plot(x3, intercept2 + slope2*x3, 'r', label='fitted line')

x4 = range(2000, 2050)
y4 = intercept2 + slope2*x4

plt.plot(x4, y4, color='red', label='fitted line')
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Rise in Sea Level')
plt.show()

# %%
slope, intercept, r, p, std_err = linregress(x, y)

def my_func(n):
    return slope * n + intercept

# Adding the sea level in 2050 on the plot
x1 = list(range(1880, 2051))
y1 = list(map(my_func, x1))

plt.plot(x1, y1)

# %%
# Create second line of best fit
index_year = x.index[x == 2000][0]  # 2000 to 2013
x2 = x[index_year:]
y2 = y[index_year:]

slope, intercept, r, p, std_err = linregress(x2, y2)

# Adding the sea level in 2050 on the plot
x2 = list(range(2000, 2051))
y2 = list(map(my_func, x2))

plt.plot(x2, y2)

# Add labels and title
plt.title("Rise in Sea Level")
plt.xlabel("Year")
plt.ylabel("Sea Level (inches)")
# Out:
# Text(0, 0.5, 'Sea Level (inches)')

# %%
plt.gca()
# Out:
# <Axes: >

# %%
x = df['Year']
y = df['CSIRO Adjusted Sea Level']

plt.scatter(x, y)

# Create first line of best fit
slope, intercept, r_value, p_value, std_err = linregress(x, y)
plt.plot(x, intercept + slope*x, 'r', label='fitted line')
  
x2 = range(1880, 2050)
y2 = intercept + slope*x2
  
plt.plot(x2, y2, color='red', label='fitted line')

# Create second line of best fit
df2 = df[df['Year'] >= 2000]

x3 = df2['Year']
y3 = df2['CSIRO Adjusted Sea Level']
  
slope2, intercept2, r_value2, p_value2, std_err2 = linregress(x3, y3)
  
plt.scatter(x3, y3)
  
plt.plot(x3, intercept2 + slope2*x3, 'r', label='fitted line')
  
x4 = range(2000, 2050)
y4 = intercept2 + slope2*x4
  
plt.plot(x4, y4, color='red', label='fitted line')
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Rise in Sea Level')

# Add labels and title

    
# Save plot and return data for testing (DO NOT MODIFY)
plt.savefig('sea_level_plot.png')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.gca().ax.get_xticks().tolist()
#
# AttributeError: 'Axes' object has no attribute 'ax'
